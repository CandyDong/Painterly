# %%
#!/usr/bin/env python3
import cv2
import random
import numpy as np
import argparse
from DRL.evaluator import Evaluator
from utils.util import *
from utils.tensorboard import TensorBoard
import time

# %%
exp = os.path.abspath('.').split('/')[-1]
writer = TensorBoard('../train_log/{}'.format(exp))
os.system('ln -sf ../train_log/{} ./log'.format(exp))
# os.system('mkdir ./model')
# Out:
# 0

# %%
def train(agent, env, evaluate):
    train_times = args.train_times
    env_batch = args.env_batch
    validate_interval = args.validate_interval
    max_step = args.max_step
    debug = args.debug
    episode_train_times = args.episode_train_times
    resume = args.resume
    output = args.output
    time_stamp = time.time()
    step = episode = episode_steps = 0
    tot_reward = 0.
    observation = None
    noise_factor = args.noise_factor
    while step <= train_times:
        step += 1
        episode_steps += 1
        # reset if it is the start of episode
        if observation is None:
            observation = env.reset()
            agent.reset(observation, noise_factor)    
        action = agent.select_action(observation, noise_factor=noise_factor)
        observation, reward, done, _ = env.step(action)
        agent.observe(reward, observation, done, step)
        if (episode_steps >= max_step and max_step):
            if step > args.warmup:
                # [optional] evaluate
                if episode > 0 and validate_interval > 0 and episode % validate_interval == 0:
                    reward, dist = evaluate(env, agent.select_action, debug=debug)
                    if debug: prRed('Step_{:07d}: mean_reward:{:.3f} mean_dist:{:.3f} var_dist:{:.3f}'.format(step - 1, np.mean(reward), np.mean(dist), np.var(dist)))
                    writer.add_scalar('validate/mean_reward', np.mean(reward), step)
                    writer.add_scalar('validate/mean_dist', np.mean(dist), step)
                    writer.add_scalar('validate/var_dist', np.var(dist), step)
                    agent.save_model(output)
            train_time_interval = time.time() - time_stamp
            time_stamp = time.time()
            tot_Q = 0.
            tot_value_loss = 0.
            if step > args.warmup:
#                 if step < 10000 * max_step:
#                     lr = (3e-4, 1e-3)
#                 elif step < 20000 * max_step:
#                     lr = (1e-4, 3e-4)
#                 else:
#                     lr = (3e-5, 1e-5)
                if step < 1000 * max_step:
                    lr = (3e-4, 1e-3)
                elif step < 2000 * max_step:
                    lr = (1e-4, 3e-4)
                else:
                    lr = (3e-5, 1e-5)
                for i in range(episode_train_times):
                    Q, value_loss = agent.update_policy(lr)
                    tot_Q += Q.data.cpu().numpy()
                    tot_value_loss += value_loss.data.cpu().numpy()
                writer.add_scalar('train/critic_lr', lr[0], step)
                writer.add_scalar('train/actor_lr', lr[1], step)
                writer.add_scalar('train/Q', tot_Q / episode_train_times, step)
                writer.add_scalar('train/critic_loss', tot_value_loss / episode_train_times, step)
            if debug: prBlack('#{}: steps:{} interval_time:{:.2f} train_time:{:.2f}' \
                .format(episode, step, train_time_interval, time.time()-time_stamp)) 
            time_stamp = time.time()
            # reset
            observation = None
            episode_steps = 0
            episode += 1

# %%
import sys
class Arg():
    def __init__(self):
        self.batch_size = 96
        self.max_step = 40
        self.warmup = 400
        self.discount = 0.95**5
        self.rmsize = 800
        self.env_batch = 96
        self.tau = 0.001
        self.noise_factor = 0;
        self.validate_interval = 50
        self.validate_episodes = 5
        self.train_times = 196000
        self.episode_train_times = 10
        self.resume = None
        self.debug = True
        self.output = './model'
        self.seed = 1234

args = Arg()
# parser = argparse.ArgumentParser(description='Learning to Paint')

# # hyper-parameter
# parser.add_argument('--warmup', default=400, type=int, help='timestep without training but only filling the replay memory')
# parser.add_argument('--discount', default=0.95**5, type=float, help='discount factor')
# parser.add_argument('--batch_size', default=96, type=int, help='minibatch size')
# parser.add_argument('--rmsize', default=800, type=int, help='replay memory size')
# parser.add_argument('--env_batch', default=96, type=int, help='concurrent environment number')
# parser.add_argument('--tau', default=0.001, type=float, help='moving average for target network')
# parser.add_argument('--max_step', default=40, type=int, help='max length for episode')
# parser.add_argument('--noise_factor', default=0, type=float, help='noise level for parameter space noise')
# parser.add_argument('--validate_interval', default=50, type=int, help='how many episodes to perform a validation')
# parser.add_argument('--validate_episodes', default=5, type=int, help='how many episode to perform during validation')
# parser.add_argument('--train_times', default=2000000, type=int, help='total traintimes')
# parser.add_argument('--episode_train_times', default=10, type=int, help='train times for each episode')    
# parser.add_argument('--resume', default=None, type=str, help='Resuming model path for testing')
# parser.add_argument('--output', default='./model', type=str, help='Resuming model path for testing')
# parser.add_argument('--debug', dest='debug', action='store_true', help='print some info')
# parser.add_argument('--seed', default=1234, type=int, help='random seed')

# args = parser.parse_args()    
# args.output = get_output_folder(args.output, "Paint")

# %%
# np.random.seed(args.seed)
# torch.manual_seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
# if torch.cuda.is_available(): torch.cuda.manual_seed_all(args.seed)
# random.seed(args.seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(args.seed)
random.seed(args.seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True
from DRL.ddpg import DDPG
from DRL.multi import fastenv
# fenv = fastenv(args.max_step, args.env_batch, writer)
# agent = DDPG(args.batch_size, args.env_batch, args.max_step, \
#              args.tau, args.discount, args.rmsize, \
#              writer, args.resume, args.output)
# evaluate = Evaluator(args, writer)
fenv = fastenv(args.max_step, args.env_batch, writer)
agent = DDPG(args.batch_size, args.env_batch, args.max_step, \
             args.tau, args.discount, args.rmsize, \
             writer, args.resume, args.output)
evaluate = Evaluator(args, writer)
print('observation_space', fenv.observation_space, 'action_space', fenv.action_space)
train(agent, fenv, evaluate)
# Out:
# loaded 10000 images
# loaded 20000 images
# loaded 30000 images
# loaded 40000 images
# loaded 50000 images
# loaded 60000 images
# loaded 70000 images
# loaded 80000 images
# loaded 90000 images
# loaded 100000 images
# loaded 110000 images
# loaded 120000 images
# loaded 130000 images
# loaded 140000 images
# loaded 150000 images
# loaded 160000 images
# loaded 170000 images
# loaded 180000 images
# loaded 190000 images
# loaded 200000 images
# finish loading data, 197999 training images, 2001 testing images
# observation_space (96, 128, 128, 7) action_space 13
# /home/ubuntu/LearningToPaint/baseline/DRL/ddpg.py:161: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s0 = torch.tensor(self.state, device='cpu')
# /home/ubuntu/LearningToPaint/baseline/DRL/ddpg.py:164: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s1 = torch.tensor(state, device='cpu')
#  #0: steps:40 interval_time:7.37 train_time:0.00
#  #1: steps:80 interval_time:5.36 train_time:0.00
#  #2: steps:120 interval_time:5.23 train_time:0.00
#  #3: steps:160 interval_time:5.48 train_time:0.00
#  #4: steps:200 interval_time:5.41 train_time:0.00
#  #5: steps:240 interval_time:5.49 train_time:0.00
#  #6: steps:280 interval_time:5.49 train_time:0.00
#  #7: steps:320 interval_time:5.22 train_time:0.00
#  #8: steps:360 interval_time:5.09 train_time:0.00
#  #9: steps:400 interval_time:4.98 train_time:0.00
#  #10: steps:440 interval_time:5.02 train_time:25.96
#  #11: steps:480 interval_time:5.00 train_time:22.75
#  #12: steps:520 interval_time:5.09 train_time:22.91
#  #13: steps:560 interval_time:5.00 train_time:22.70
#  #14: steps:600 interval_time:5.06 train_time:22.53
#  #15: steps:640 interval_time:4.94 train_time:22.89
#  #16: steps:680 interval_time:5.00 train_time:22.68
#  #17: steps:720 interval_time:5.04 train_time:22.67
#  #18: steps:760 interval_time:5.19 train_time:22.75
#  #19: steps:800 interval_time:4.90 train_time:22.76
#  #20: steps:840 interval_time:4.99 train_time:22.66
#  #21: steps:880 interval_time:5.05 train_time:22.62
#  #22: steps:920 interval_time:5.03 train_time:22.49
#  #23: steps:960 interval_time:5.12 train_time:22.80
#  #24: steps:1000 interval_time:5.01 train_time:22.83
#  #25: steps:1040 interval_time:5.04 train_time:22.74
#  #26: steps:1080 interval_time:4.95 train_time:22.50
#  #27: steps:1120 interval_time:5.22 train_time:22.58
#  #28: steps:1160 interval_time:5.22 train_time:22.76
#  #29: steps:1200 interval_time:5.13 train_time:22.52
#  #30: steps:1240 interval_time:5.15 train_time:22.75
#  #31: steps:1280 interval_time:5.03 train_time:22.80
#  #32: steps:1320 interval_time:5.23 train_time:22.82
#  #33: steps:1360 interval_time:5.06 train_time:22.87
#  #34: steps:1400 interval_time:5.00 train_time:22.81
#  #35: steps:1440 interval_time:5.00 train_time:22.45
#  #36: steps:1480 interval_time:5.17 train_time:22.89
#  #37: steps:1520 interval_time:5.12 train_time:22.79
#  #38: steps:1560 interval_time:5.01 train_time:22.85
#  #39: steps:1600 interval_time:5.18 train_time:22.79
#  #40: steps:1640 interval_time:5.01 train_time:22.70
#  #41: steps:1680 interval_time:5.07 train_time:22.44
#  #42: steps:1720 interval_time:4.95 train_time:22.63
#  #43: steps:1760 interval_time:5.12 train_time:22.67
#  #44: steps:1800 interval_time:5.03 train_time:22.62
#  #45: steps:1840 interval_time:4.99 train_time:22.76
#  #46: steps:1880 interval_time:5.21 train_time:22.89
#  #47: steps:1920 interval_time:5.18 train_time:22.62
#  #48: steps:1960 interval_time:4.98 train_time:22.68
#  #49: steps:2000 interval_time:4.93 train_time:22.91
#  Step_0002039: mean_reward:0.561 mean_dist:0.106 var_dist:0.001
#  #50: steps:2040 interval_time:33.61 train_time:22.61
#  #51: steps:2080 interval_time:4.96 train_time:22.67
#  #52: steps:2120 interval_time:5.16 train_time:22.24
#  #53: steps:2160 interval_time:5.10 train_time:22.83
#  #54: steps:2200 interval_time:5.12 train_time:22.75
#  #55: steps:2240 interval_time:5.02 train_time:22.65
#  #56: steps:2280 interval_time:5.13 train_time:22.84
#  #57: steps:2320 interval_time:5.09 train_time:22.36
#  #58: steps:2360 interval_time:5.08 train_time:22.81
#  #59: steps:2400 interval_time:5.03 train_time:22.65
#  #60: steps:2440 interval_time:5.07 train_time:22.60
#  #61: steps:2480 interval_time:5.25 train_time:22.80
#  #62: steps:2520 interval_time:5.07 train_time:22.74
#  #63: steps:2560 interval_time:4.97 train_time:22.86
#  #64: steps:2600 interval_time:5.22 train_time:22.67
#  #65: steps:2640 interval_time:5.05 train_time:22.79
#  #66: steps:2680 interval_time:5.00 train_time:22.78
#  #67: steps:2720 interval_time:5.09 train_time:22.74
#  #68: steps:2760 interval_time:5.07 train_time:22.62
#  #69: steps:2800 interval_time:5.17 train_time:22.90
#  #70: steps:2840 interval_time:4.93 train_time:22.69
#  #71: steps:2880 interval_time:5.05 train_time:22.27
#  #72: steps:2920 interval_time:4.94 train_time:22.15
#  #73: steps:2960 interval_time:4.92 train_time:22.66
#  #74: steps:3000 interval_time:5.09 train_time:22.82
#  #75: steps:3040 interval_time:5.04 train_time:22.73
#  #76: steps:3080 interval_time:5.11 train_time:22.30
#  #77: steps:3120 interval_time:5.25 train_time:22.79
#  #78: steps:3160 interval_time:5.05 train_time:22.86
#  #79: steps:3200 interval_time:5.17 train_time:22.80
#  #80: steps:3240 interval_time:5.15 train_time:22.49
#  #81: steps:3280 interval_time:5.13 train_time:22.69
#  #82: steps:3320 interval_time:5.11 train_time:22.59
#  #83: steps:3360 interval_time:5.10 train_time:22.64
#  #84: steps:3400 interval_time:5.02 train_time:22.75
#  #85: steps:3440 interval_time:5.08 train_time:22.85
#  #86: steps:3480 interval_time:5.15 train_time:22.76
#  #87: steps:3520 interval_time:5.08 train_time:22.83
#  #88: steps:3560 interval_time:5.02 train_time:22.60
#  #89: steps:3600 interval_time:5.19 train_time:22.56
#  #90: steps:3640 interval_time:4.99 train_time:22.81
#  #91: steps:3680 interval_time:5.06 train_time:22.78
#  #92: steps:3720 interval_time:5.10 train_time:22.36
#  #93: steps:3760 interval_time:5.22 train_time:22.50
#  #94: steps:3800 interval_time:5.16 train_time:22.68
#  #95: steps:3840 interval_time:4.98 train_time:22.56
#  #96: steps:3880 interval_time:5.22 train_time:22.57
#  #97: steps:3920 interval_time:5.06 train_time:22.76
#  #98: steps:3960 interval_time:5.02 train_time:22.67
#  #99: steps:4000 interval_time:5.09 train_time:22.45
#  Step_0004039: mean_reward:0.838 mean_dist:0.042 var_dist:0.000
#  #100: steps:4040 interval_time:33.20 train_time:22.75
#  #101: steps:4080 interval_time:5.11 train_time:22.61
#  #102: steps:4120 interval_time:5.21 train_time:22.75
#  #103: steps:4160 interval_time:5.17 train_time:22.72
#  #104: steps:4200 interval_time:5.02 train_time:22.70
#  #105: steps:4240 interval_time:4.93 train_time:22.68
#  #106: steps:4280 interval_time:5.00 train_time:22.85
#  #107: steps:4320 interval_time:5.16 train_time:22.80
#  #108: steps:4360 interval_time:5.15 train_time:22.34
#  #109: steps:4400 interval_time:5.02 train_time:22.83
#  #110: steps:4440 interval_time:5.07 train_time:22.58
#  #111: steps:4480 interval_time:5.09 train_time:22.64
#  #112: steps:4520 interval_time:4.87 train_time:22.62
#  #113: steps:4560 interval_time:5.03 train_time:22.65
#  #114: steps:4600 interval_time:5.03 train_time:22.78
#  #115: steps:4640 interval_time:5.08 train_time:22.46
#  #116: steps:4680 interval_time:5.15 train_time:22.48
#  #117: steps:4720 interval_time:5.16 train_time:22.50
#  #118: steps:4760 interval_time:4.99 train_time:22.61
#  #119: steps:4800 interval_time:4.97 train_time:22.62
#  #120: steps:4840 interval_time:5.16 train_time:22.48
#  #121: steps:4880 interval_time:4.94 train_time:22.88
#  #122: steps:4920 interval_time:5.21 train_time:22.83
#  #123: steps:4960 interval_time:5.01 train_time:22.86
#  #124: steps:5000 interval_time:5.05 train_time:22.76
#  #125: steps:5040 interval_time:5.18 train_time:22.63
#  #126: steps:5080 interval_time:4.95 train_time:22.65
#  #127: steps:5120 interval_time:5.05 train_time:22.65
#  #128: steps:5160 interval_time:5.06 train_time:22.75
#  #129: steps:5200 interval_time:5.09 train_time:22.68
#  #130: steps:5240 interval_time:5.02 train_time:22.72
#  #131: steps:5280 interval_time:5.09 train_time:22.43
#  #132: steps:5320 interval_time:5.16 train_time:22.83
#  #133: steps:5360 interval_time:4.97 train_time:22.84
#  #134: steps:5400 interval_time:4.95 train_time:22.75
#  #135: steps:5440 interval_time:5.23 train_time:22.83
#  #136: steps:5480 interval_time:5.04 train_time:22.80
#  #137: steps:5520 interval_time:4.95 train_time:22.69
#  #138: steps:5560 interval_time:5.11 train_time:22.64
#  #139: steps:5600 interval_time:5.08 train_time:22.63
#  #140: steps:5640 interval_time:5.00 train_time:22.69
#  #141: steps:5680 interval_time:4.99 train_time:22.77
#  #142: steps:5720 interval_time:5.06 train_time:22.80
#  #143: steps:5760 interval_time:5.14 train_time:22.83
#  #144: steps:5800 interval_time:5.06 train_time:22.72
#  #145: steps:5840 interval_time:5.15 train_time:22.65
#  #146: steps:5880 interval_time:4.99 train_time:22.78
#  #147: steps:5920 interval_time:5.18 train_time:22.75
#  #148: steps:5960 interval_time:5.11 train_time:22.94
#  #149: steps:6000 interval_time:5.05 train_time:22.63
#  Step_0006039: mean_reward:0.849 mean_dist:0.038 var_dist:0.000
#  #150: steps:6040 interval_time:33.25 train_time:22.58
#  #151: steps:6080 interval_time:4.97 train_time:22.88
#  #152: steps:6120 interval_time:5.09 train_time:22.85
#  #153: steps:6160 interval_time:4.99 train_time:22.89
#  #154: steps:6200 interval_time:5.10 train_time:22.89
#  #155: steps:6240 interval_time:5.01 train_time:22.71
#  #156: steps:6280 interval_time:5.02 train_time:22.88
#  #157: steps:6320 interval_time:4.94 train_time:22.65
#  #158: steps:6360 interval_time:5.06 train_time:22.80
#  #159: steps:6400 interval_time:5.28 train_time:22.73
#  #160: steps:6440 interval_time:5.03 train_time:22.84
#  #161: steps:6480 interval_time:5.23 train_time:22.91
#  #162: steps:6520 interval_time:5.25 train_time:22.80
#  #163: steps:6560 interval_time:5.00 train_time:22.40
#  #164: steps:6600 interval_time:5.21 train_time:22.64
#  #165: steps:6640 interval_time:5.03 train_time:22.69
#  #166: steps:6680 interval_time:5.14 train_time:22.80
#  #167: steps:6720 interval_time:5.18 train_time:22.79
#  #168: steps:6760 interval_time:5.11 train_time:22.82
#  #169: steps:6800 interval_time:5.01 train_time:22.84
#  #170: steps:6840 interval_time:5.15 train_time:22.93
#  #171: steps:6880 interval_time:5.01 train_time:22.65
#  #172: steps:6920 interval_time:5.00 train_time:22.71
#  #173: steps:6960 interval_time:5.05 train_time:22.70
#  #174: steps:7000 interval_time:5.03 train_time:22.63
#  #175: steps:7040 interval_time:5.23 train_time:22.65
#  #176: steps:7080 interval_time:5.22 train_time:22.72
#  #177: steps:7120 interval_time:4.97 train_time:22.79
#  #178: steps:7160 interval_time:5.00 train_time:22.80
#  #179: steps:7200 interval_time:5.16 train_time:22.80
#  #180: steps:7240 interval_time:4.99 train_time:22.93
#  #181: steps:7280 interval_time:4.96 train_time:22.59
#  #182: steps:7320 interval_time:5.20 train_time:22.62
#  #183: steps:7360 interval_time:5.14 train_time:22.71
#  #184: steps:7400 interval_time:5.05 train_time:22.70
#  #185: steps:7440 interval_time:5.04 train_time:22.81
#  #186: steps:7480 interval_time:5.19 train_time:22.81
#  #187: steps:7520 interval_time:5.00 train_time:22.73
#  #188: steps:7560 interval_time:5.22 train_time:22.81
#  #189: steps:7600 interval_time:5.12 train_time:22.68
#  #190: steps:7640 interval_time:5.08 train_time:22.88
#  #191: steps:7680 interval_time:5.22 train_time:22.76
#  #192: steps:7720 interval_time:5.16 train_time:22.43
#  #193: steps:7760 interval_time:5.02 train_time:22.39
#  #194: steps:7800 interval_time:5.11 train_time:22.54
#  #195: steps:7840 interval_time:5.18 train_time:22.76
#  #196: steps:7880 interval_time:5.00 train_time:22.67
#  #197: steps:7920 interval_time:5.00 train_time:22.72
#  #198: steps:7960 interval_time:5.11 train_time:22.59
#  #199: steps:8000 interval_time:4.99 train_time:22.55
#  Step_0008039: mean_reward:0.860 mean_dist:0.034 var_dist:0.000
#  #200: steps:8040 interval_time:33.42 train_time:22.33
#  #201: steps:8080 interval_time:5.13 train_time:22.78
#  #202: steps:8120 interval_time:5.00 train_time:22.83
#  #203: steps:8160 interval_time:4.94 train_time:22.80
#  #204: steps:8200 interval_time:5.20 train_time:22.90
#  #205: steps:8240 interval_time:4.99 train_time:22.80
#  #206: steps:8280 interval_time:5.10 train_time:22.64
#  #207: steps:8320 interval_time:4.95 train_time:22.60
#  #208: steps:8360 interval_time:5.09 train_time:22.74
#  #209: steps:8400 interval_time:5.03 train_time:22.96
#  #210: steps:8440 interval_time:5.10 train_time:22.82
#  #211: steps:8480 interval_time:5.03 train_time:22.54
#  #212: steps:8520 interval_time:5.13 train_time:22.83
#  #213: steps:8560 interval_time:5.15 train_time:22.74
#  #214: steps:8600 interval_time:5.17 train_time:22.87
#  #215: steps:8640 interval_time:5.16 train_time:22.85
#  #216: steps:8680 interval_time:4.96 train_time:22.70
#  #217: steps:8720 interval_time:4.97 train_time:22.90
#  #218: steps:8760 interval_time:5.24 train_time:22.84
#  #219: steps:8800 interval_time:5.19 train_time:22.42
#  #220: steps:8840 interval_time:5.02 train_time:22.85
#  #221: steps:8880 interval_time:5.14 train_time:22.93
#  #222: steps:8920 interval_time:5.18 train_time:22.53
#  #223: steps:8960 interval_time:5.16 train_time:22.83
#  #224: steps:9000 interval_time:5.25 train_time:22.89
#  #225: steps:9040 interval_time:5.24 train_time:22.63
#  #226: steps:9080 interval_time:5.08 train_time:22.83
#  #227: steps:9120 interval_time:5.17 train_time:22.69
#  #228: steps:9160 interval_time:5.14 train_time:22.84
#  #229: steps:9200 interval_time:4.97 train_time:22.42
#  #230: steps:9240 interval_time:5.08 train_time:22.33
#  #231: steps:9280 interval_time:5.09 train_time:22.70
#  #232: steps:9320 interval_time:5.07 train_time:22.74
#  #233: steps:9360 interval_time:5.04 train_time:22.93
#  #234: steps:9400 interval_time:5.12 train_time:22.66
#  #235: steps:9440 interval_time:5.01 train_time:22.92
#  #236: steps:9480 interval_time:5.06 train_time:22.85
#  #237: steps:9520 interval_time:5.02 train_time:22.66
#  #238: steps:9560 interval_time:5.17 train_time:22.74
#  #239: steps:9600 interval_time:5.00 train_time:22.58
#  #240: steps:9640 interval_time:5.24 train_time:22.55
#  #241: steps:9680 interval_time:5.06 train_time:22.46
#  #242: steps:9720 interval_time:5.08 train_time:22.45
#  #243: steps:9760 interval_time:5.00 train_time:22.69
#  #244: steps:9800 interval_time:5.15 train_time:22.63
#  #245: steps:9840 interval_time:5.17 train_time:22.85
#  #246: steps:9880 interval_time:5.17 train_time:22.83
#  #247: steps:9920 interval_time:5.14 train_time:22.41
#  #248: steps:9960 interval_time:5.16 train_time:22.71
#  #249: steps:10000 interval_time:5.22 train_time:22.66
#  Step_0010039: mean_reward:0.869 mean_dist:0.033 var_dist:0.000
#  #250: steps:10040 interval_time:33.83 train_time:22.78
#  #251: steps:10080 interval_time:5.06 train_time:22.58
#  #252: steps:10120 interval_time:5.08 train_time:22.31
#  #253: steps:10160 interval_time:4.98 train_time:22.62
#  #254: steps:10200 interval_time:4.99 train_time:22.76
#  #255: steps:10240 interval_time:5.08 train_time:22.77
#  #256: steps:10280 interval_time:5.05 train_time:22.73
#  #257: steps:10320 interval_time:5.13 train_time:22.70
#  #258: steps:10360 interval_time:5.13 train_time:22.91
#  #259: steps:10400 interval_time:5.33 train_time:22.67
#  #260: steps:10440 interval_time:4.99 train_time:22.87
#  #261: steps:10480 interval_time:5.01 train_time:22.60
#  #262: steps:10520 interval_time:5.04 train_time:22.74
#  #263: steps:10560 interval_time:5.06 train_time:22.73
#  #264: steps:10600 interval_time:5.01 train_time:22.38
#  #265: steps:10640 interval_time:5.07 train_time:22.50
#  #266: steps:10680 interval_time:5.10 train_time:22.68
#  #267: steps:10720 interval_time:5.33 train_time:22.78
#  #268: steps:10760 interval_time:5.20 train_time:22.54
#  #269: steps:10800 interval_time:5.20 train_time:22.81
#  #270: steps:10840 interval_time:5.07 train_time:22.79
#  #271: steps:10880 interval_time:4.96 train_time:22.80
#  #272: steps:10920 interval_time:5.09 train_time:22.52
#  #273: steps:10960 interval_time:5.09 train_time:22.75
#  #274: steps:11000 interval_time:4.97 train_time:22.83
#  #275: steps:11040 interval_time:5.07 train_time:22.90
#  #276: steps:11080 interval_time:4.98 train_time:22.62
#  #277: steps:11120 interval_time:5.01 train_time:22.63
#  #278: steps:11160 interval_time:4.98 train_time:22.81
#  #279: steps:11200 interval_time:5.04 train_time:22.54
#  #280: steps:11240 interval_time:5.25 train_time:22.75
#  #281: steps:11280 interval_time:5.14 train_time:22.81
#  #282: steps:11320 interval_time:5.00 train_time:22.54
#  #283: steps:11360 interval_time:5.01 train_time:22.54
#  #284: steps:11400 interval_time:5.03 train_time:22.60
#  #285: steps:11440 interval_time:5.05 train_time:22.77
#  #286: steps:11480 interval_time:4.98 train_time:22.77
#  #287: steps:11520 interval_time:5.15 train_time:22.67
#  #288: steps:11560 interval_time:4.97 train_time:22.69
#  #289: steps:11600 interval_time:5.02 train_time:22.48
#  #290: steps:11640 interval_time:5.04 train_time:22.83
#  #291: steps:11680 interval_time:5.19 train_time:22.30
#  #292: steps:11720 interval_time:5.23 train_time:22.76
#  #293: steps:11760 interval_time:5.01 train_time:22.87
#  #294: steps:11800 interval_time:5.00 train_time:22.45
#  #295: steps:11840 interval_time:5.14 train_time:22.57
#  #296: steps:11880 interval_time:5.12 train_time:22.59
#  #297: steps:11920 interval_time:5.27 train_time:22.69
#  #298: steps:11960 interval_time:5.00 train_time:22.84
#  #299: steps:12000 interval_time:5.15 train_time:22.91
#  Step_0012039: mean_reward:0.873 mean_dist:0.032 var_dist:0.000
#  #300: steps:12040 interval_time:34.60 train_time:22.47
#  #301: steps:12080 interval_time:5.10 train_time:22.72
#  #302: steps:12120 interval_time:5.04 train_time:22.70
#  #303: steps:12160 interval_time:5.01 train_time:22.61
#  #304: steps:12200 interval_time:5.05 train_time:22.75
#  #305: steps:12240 interval_time:5.01 train_time:22.61
#  #306: steps:12280 interval_time:4.99 train_time:22.76
#  #307: steps:12320 interval_time:5.13 train_time:22.73
#  #308: steps:12360 interval_time:5.22 train_time:22.63
#  #309: steps:12400 interval_time:5.15 train_time:22.89
#  #310: steps:12440 interval_time:4.98 train_time:22.55
#  #311: steps:12480 interval_time:5.00 train_time:22.67
#  #312: steps:12520 interval_time:5.01 train_time:22.65
#  #313: steps:12560 interval_time:5.08 train_time:22.76
#  #314: steps:12600 interval_time:5.04 train_time:22.69
#  #315: steps:12640 interval_time:5.03 train_time:22.67
#  #316: steps:12680 interval_time:4.95 train_time:22.14
#  #317: steps:12720 interval_time:5.09 train_time:22.30
#  #318: steps:12760 interval_time:5.06 train_time:22.57
#  #319: steps:12800 interval_time:4.97 train_time:22.68
#  #320: steps:12840 interval_time:4.97 train_time:22.83
#  #321: steps:12880 interval_time:5.03 train_time:22.63
#  #322: steps:12920 interval_time:5.01 train_time:22.80
#  #323: steps:12960 interval_time:5.04 train_time:22.62
#  #324: steps:13000 interval_time:5.19 train_time:22.71
#  #325: steps:13040 interval_time:5.23 train_time:22.56
#  #326: steps:13080 interval_time:5.00 train_time:22.48
#  #327: steps:13120 interval_time:5.18 train_time:22.63
#  #328: steps:13160 interval_time:5.16 train_time:22.56
#  #329: steps:13200 interval_time:5.09 train_time:22.52
#  #330: steps:13240 interval_time:4.99 train_time:22.52
#  #331: steps:13280 interval_time:5.04 train_time:22.43
#  #332: steps:13320 interval_time:5.20 train_time:22.86
#  #333: steps:13360 interval_time:5.04 train_time:22.86
#  #334: steps:13400 interval_time:5.00 train_time:22.71
#  #335: steps:13440 interval_time:5.02 train_time:22.36
#  #336: steps:13480 interval_time:5.02 train_time:22.51
#  #337: steps:13520 interval_time:5.00 train_time:22.37
#  #338: steps:13560 interval_time:5.06 train_time:22.19
#  #339: steps:13600 interval_time:5.00 train_time:22.65
#  #340: steps:13640 interval_time:5.11 train_time:22.62
#  #341: steps:13680 interval_time:5.24 train_time:22.65
#  #342: steps:13720 interval_time:5.04 train_time:22.81
#  #343: steps:13760 interval_time:4.97 train_time:22.86
#  #344: steps:13800 interval_time:5.25 train_time:22.48
#  #345: steps:13840 interval_time:5.02 train_time:22.55
#  #346: steps:13880 interval_time:5.07 train_time:22.73
#  #347: steps:13920 interval_time:5.13 train_time:22.76
#  #348: steps:13960 interval_time:5.14 train_time:22.88
#  #349: steps:14000 interval_time:5.01 train_time:22.68
#  Step_0014039: mean_reward:0.877 mean_dist:0.030 var_dist:0.000
#  #350: steps:14040 interval_time:33.28 train_time:22.80
#  #351: steps:14080 interval_time:5.16 train_time:22.75
#  #352: steps:14120 interval_time:4.95 train_time:22.61
#  #353: steps:14160 interval_time:5.20 train_time:22.58
#  #354: steps:14200 interval_time:5.04 train_time:22.75
#  #355: steps:14240 interval_time:4.97 train_time:22.53
#  #356: steps:14280 interval_time:5.01 train_time:22.80
#  #357: steps:14320 interval_time:4.97 train_time:22.97
#  #358: steps:14360 interval_time:5.21 train_time:22.79
#  #359: steps:14400 interval_time:5.16 train_time:22.67
#  #360: steps:14440 interval_time:4.94 train_time:22.46
#  #361: steps:14480 interval_time:4.52 train_time:19.55
#  #362: steps:14520 interval_time:4.45 train_time:19.53
#  #363: steps:14560 interval_time:4.45 train_time:19.52
#  #364: steps:14600 interval_time:4.43 train_time:19.51
#  #365: steps:14640 interval_time:4.44 train_time:19.52
#  #366: steps:14680 interval_time:4.43 train_time:19.54
#  #367: steps:14720 interval_time:4.44 train_time:19.54
#  #368: steps:14760 interval_time:4.47 train_time:19.51
#  #369: steps:14800 interval_time:4.44 train_time:19.52
#  #370: steps:14840 interval_time:4.46 train_time:19.53
#  #371: steps:14880 interval_time:4.44 train_time:19.51
#  #372: steps:14920 interval_time:4.43 train_time:19.53
#  #373: steps:14960 interval_time:4.43 train_time:19.53
#  #374: steps:15000 interval_time:4.48 train_time:19.53
#  #375: steps:15040 interval_time:4.43 train_time:19.52
#  #376: steps:15080 interval_time:4.43 train_time:19.51
#  #377: steps:15120 interval_time:4.43 train_time:19.51
#  #378: steps:15160 interval_time:4.43 train_time:19.52
#  #379: steps:15200 interval_time:4.43 train_time:19.52
#  #380: steps:15240 interval_time:4.43 train_time:19.49
#  #381: steps:15280 interval_time:4.44 train_time:19.53
#  #382: steps:15320 interval_time:4.43 train_time:19.55
#  #383: steps:15360 interval_time:4.44 train_time:19.56
#  #384: steps:15400 interval_time:4.45 train_time:19.53
#  #385: steps:15440 interval_time:4.45 train_time:19.52
#  #386: steps:15480 interval_time:4.50 train_time:19.55
#  #387: steps:15520 interval_time:4.45 train_time:19.50
#  #388: steps:15560 interval_time:4.44 train_time:19.51
#  #389: steps:15600 interval_time:4.49 train_time:19.50
#  #390: steps:15640 interval_time:4.43 train_time:19.52
#  #391: steps:15680 interval_time:4.43 train_time:19.52
#  #392: steps:15720 interval_time:4.44 train_time:19.51
#  #393: steps:15760 interval_time:4.46 train_time:19.51
#  #394: steps:15800 interval_time:4.43 train_time:19.52
#  #395: steps:15840 interval_time:4.44 train_time:19.51
#  #396: steps:15880 interval_time:4.43 train_time:19.52
#  #397: steps:15920 interval_time:4.43 train_time:19.51
#  #398: steps:15960 interval_time:4.44 train_time:19.53
#  #399: steps:16000 interval_time:4.44 train_time:19.53
#  Step_0016039: mean_reward:0.886 mean_dist:0.028 var_dist:0.000
#  #400: steps:16040 interval_time:30.14 train_time:19.53
#  #401: steps:16080 interval_time:4.45 train_time:19.50
#  #402: steps:16120 interval_time:4.47 train_time:19.50
#  #403: steps:16160 interval_time:4.49 train_time:19.51
#  #404: steps:16200 interval_time:4.50 train_time:19.57
#  #405: steps:16240 interval_time:4.52 train_time:19.53
#  #406: steps:16280 interval_time:4.43 train_time:19.51
#  #407: steps:16320 interval_time:4.44 train_time:19.53
#  #408: steps:16360 interval_time:4.49 train_time:19.54
#  #409: steps:16400 interval_time:4.52 train_time:19.52
#  #410: steps:16440 interval_time:4.53 train_time:19.53
#  #411: steps:16480 interval_time:4.43 train_time:19.53
#  #412: steps:16520 interval_time:4.43 train_time:19.53
#  #413: steps:16560 interval_time:4.43 train_time:19.52
#  #414: steps:16600 interval_time:4.43 train_time:19.53
#  #415: steps:16640 interval_time:4.48 train_time:19.53
#  #416: steps:16680 interval_time:4.45 train_time:19.51
#  #417: steps:16720 interval_time:4.43 train_time:19.52
#  #418: steps:16760 interval_time:4.51 train_time:19.54
#  #419: steps:16800 interval_time:4.51 train_time:19.53
#  #420: steps:16840 interval_time:4.46 train_time:19.53
#  #421: steps:16880 interval_time:4.46 train_time:19.52
#  #422: steps:16920 interval_time:4.47 train_time:19.53
#  #423: steps:16960 interval_time:4.52 train_time:19.56
#  #424: steps:17000 interval_time:4.52 train_time:19.52
#  #425: steps:17040 interval_time:4.51 train_time:19.53
#  #426: steps:17080 interval_time:4.44 train_time:19.54
#  #427: steps:17120 interval_time:4.48 train_time:19.54
#  #428: steps:17160 interval_time:4.45 train_time:19.52
#  #429: steps:17200 interval_time:4.45 train_time:19.53
#  #430: steps:17240 interval_time:4.45 train_time:19.53
#  #431: steps:17280 interval_time:4.44 train_time:19.53
#  #432: steps:17320 interval_time:4.44 train_time:19.55
#  #433: steps:17360 interval_time:4.48 train_time:19.55
#  #434: steps:17400 interval_time:4.44 train_time:19.57
#  #435: steps:17440 interval_time:4.46 train_time:19.53
#  #436: steps:17480 interval_time:4.51 train_time:19.54
#  #437: steps:17520 interval_time:4.53 train_time:19.53
#  #438: steps:17560 interval_time:4.55 train_time:19.55
#  #439: steps:17600 interval_time:4.52 train_time:19.57
#  #440: steps:17640 interval_time:4.55 train_time:19.55
#  #441: steps:17680 interval_time:4.45 train_time:19.55
#  #442: steps:17720 interval_time:4.45 train_time:19.56
#  #443: steps:17760 interval_time:4.48 train_time:19.56
#  #444: steps:17800 interval_time:4.45 train_time:19.51
#  #445: steps:17840 interval_time:4.53 train_time:19.54
#  #446: steps:17880 interval_time:4.43 train_time:19.54
#  #447: steps:17920 interval_time:4.45 train_time:19.53
#  #448: steps:17960 interval_time:4.46 train_time:19.53
#  #449: steps:18000 interval_time:4.49 train_time:19.54
#  Step_0018039: mean_reward:0.887 mean_dist:0.028 var_dist:0.000
#  #450: steps:18040 interval_time:29.87 train_time:19.53
#  #451: steps:18080 interval_time:4.48 train_time:19.54
#  #452: steps:18120 interval_time:4.43 train_time:19.53
#  #453: steps:18160 interval_time:4.48 train_time:19.52
#  #454: steps:18200 interval_time:4.45 train_time:19.56
#  #455: steps:18240 interval_time:4.45 train_time:19.53
#  #456: steps:18280 interval_time:4.44 train_time:19.55
#  #457: steps:18320 interval_time:4.44 train_time:19.56
#  #458: steps:18360 interval_time:4.49 train_time:19.54
#  #459: steps:18400 interval_time:4.47 train_time:19.55
#  #460: steps:18440 interval_time:4.51 train_time:19.54
#  #461: steps:18480 interval_time:4.44 train_time:19.52
#  #462: steps:18520 interval_time:4.52 train_time:19.53
#  #463: steps:18560 interval_time:4.56 train_time:19.53
#  #464: steps:18600 interval_time:4.43 train_time:19.56
#  #465: steps:18640 interval_time:4.48 train_time:19.54
#  #466: steps:18680 interval_time:4.51 train_time:19.55
#  #467: steps:18720 interval_time:4.54 train_time:19.56
#  #468: steps:18760 interval_time:4.58 train_time:19.54
#  #469: steps:18800 interval_time:4.57 train_time:19.55
#  #470: steps:18840 interval_time:4.46 train_time:19.53
#  #471: steps:18880 interval_time:4.44 train_time:19.55
#  #472: steps:18920 interval_time:4.46 train_time:19.53
#  #473: steps:18960 interval_time:4.44 train_time:19.52
#  #474: steps:19000 interval_time:4.53 train_time:19.52
#  #475: steps:19040 interval_time:4.45 train_time:19.53
#  #476: steps:19080 interval_time:4.49 train_time:19.53
#  #477: steps:19120 interval_time:4.46 train_time:19.52
#  #478: steps:19160 interval_time:4.54 train_time:19.52
#  #479: steps:19200 interval_time:4.52 train_time:19.53
#  #480: steps:19240 interval_time:4.46 train_time:19.57
#  #481: steps:19280 interval_time:4.48 train_time:19.55
#  #482: steps:19320 interval_time:4.54 train_time:19.56
#  #483: steps:19360 interval_time:4.48 train_time:19.52
#  #484: steps:19400 interval_time:4.45 train_time:19.53
#  #485: steps:19440 interval_time:4.54 train_time:19.54
#  #486: steps:19480 interval_time:4.46 train_time:19.53
#  #487: steps:19520 interval_time:4.46 train_time:19.54
#  #488: steps:19560 interval_time:4.46 train_time:19.52
#  #489: steps:19600 interval_time:4.52 train_time:19.54
#  #490: steps:19640 interval_time:4.49 train_time:19.52
#  #491: steps:19680 interval_time:4.51 train_time:19.52
#  #492: steps:19720 interval_time:4.45 train_time:19.56
#  #493: steps:19760 interval_time:4.46 train_time:19.53
#  #494: steps:19800 interval_time:4.45 train_time:19.54
#  #495: steps:19840 interval_time:4.45 train_time:19.52
#  #496: steps:19880 interval_time:4.46 train_time:19.53
#  #497: steps:19920 interval_time:4.44 train_time:19.53
#  #498: steps:19960 interval_time:4.44 train_time:19.54
#  #499: steps:20000 interval_time:4.46 train_time:19.55
#  Step_0020039: mean_reward:0.891 mean_dist:0.026 var_dist:0.000
#  #500: steps:20040 interval_time:30.18 train_time:19.52
#  #501: steps:20080 interval_time:4.46 train_time:19.52
#  #502: steps:20120 interval_time:4.51 train_time:19.53
#  #503: steps:20160 interval_time:4.49 train_time:19.54
#  #504: steps:20200 interval_time:4.44 train_time:19.53
#  #505: steps:20240 interval_time:4.50 train_time:19.51
#  #506: steps:20280 interval_time:4.44 train_time:19.53
#  #507: steps:20320 interval_time:4.45 train_time:19.52
#  #508: steps:20360 interval_time:4.46 train_time:19.51
#  #509: steps:20400 interval_time:4.46 train_time:19.49
#  #510: steps:20440 interval_time:4.54 train_time:19.50
#  #511: steps:20480 interval_time:4.44 train_time:19.51
#  #512: steps:20520 interval_time:4.44 train_time:19.51
#  #513: steps:20560 interval_time:4.43 train_time:19.50
#  #514: steps:20600 interval_time:4.45 train_time:19.50
#  #515: steps:20640 interval_time:4.56 train_time:19.49
#  #516: steps:20680 interval_time:4.51 train_time:19.49
#  #517: steps:20720 interval_time:4.43 train_time:19.49
#  #518: steps:20760 interval_time:4.43 train_time:19.51
#  #519: steps:20800 interval_time:4.43 train_time:19.49
#  #520: steps:20840 interval_time:4.43 train_time:19.51
#  #521: steps:20880 interval_time:4.47 train_time:19.50
#  #522: steps:20920 interval_time:4.52 train_time:19.49
#  #523: steps:20960 interval_time:4.52 train_time:19.53
#  #524: steps:21000 interval_time:4.50 train_time:19.53
#  #525: steps:21040 interval_time:4.51 train_time:19.51
#  #526: steps:21080 interval_time:4.52 train_time:19.52
#  #527: steps:21120 interval_time:4.52 train_time:19.52
#  #528: steps:21160 interval_time:4.50 train_time:19.53
#  #529: steps:21200 interval_time:4.46 train_time:19.53
#  #530: steps:21240 interval_time:4.53 train_time:19.54
#  #531: steps:21280 interval_time:4.47 train_time:19.56
#  #532: steps:21320 interval_time:4.48 train_time:19.53
#  #533: steps:21360 interval_time:4.47 train_time:19.53
#  #534: steps:21400 interval_time:4.46 train_time:19.54
#  #535: steps:21440 interval_time:4.44 train_time:19.53
#  #536: steps:21480 interval_time:4.47 train_time:19.58
#  #537: steps:21520 interval_time:4.54 train_time:19.54
#  #538: steps:21560 interval_time:4.46 train_time:19.54
#  #539: steps:21600 interval_time:4.43 train_time:19.53
#  #540: steps:21640 interval_time:4.43 train_time:19.53
#  #541: steps:21680 interval_time:4.45 train_time:19.51
#  #542: steps:21720 interval_time:4.43 train_time:19.52
#  #543: steps:21760 interval_time:4.43 train_time:19.51
#  #544: steps:21800 interval_time:4.45 train_time:19.51
#  #545: steps:21840 interval_time:4.51 train_time:19.52
#  #546: steps:21880 interval_time:4.48 train_time:19.53
#  #547: steps:21920 interval_time:4.42 train_time:19.51
#  #548: steps:21960 interval_time:4.43 train_time:19.51
#  #549: steps:22000 interval_time:4.43 train_time:19.53
#  Step_0022039: mean_reward:0.896 mean_dist:0.026 var_dist:0.000
#  #550: steps:22040 interval_time:30.67 train_time:19.51
#  #551: steps:22080 interval_time:4.51 train_time:19.50
#  #552: steps:22120 interval_time:4.43 train_time:19.51
#  #553: steps:22160 interval_time:4.44 train_time:19.49
#  #554: steps:22200 interval_time:4.48 train_time:19.52
#  #555: steps:22240 interval_time:4.49 train_time:19.50
#  #556: steps:22280 interval_time:4.48 train_time:19.52
#  #557: steps:22320 interval_time:4.54 train_time:19.50
#  #558: steps:22360 interval_time:4.44 train_time:19.52
#  #559: steps:22400 interval_time:4.50 train_time:19.50
#  #560: steps:22440 interval_time:4.50 train_time:19.52
#  #561: steps:22480 interval_time:4.43 train_time:19.51
#  #562: steps:22520 interval_time:4.46 train_time:19.52
#  #563: steps:22560 interval_time:4.43 train_time:19.52
#  #564: steps:22600 interval_time:4.44 train_time:19.53
#  #565: steps:22640 interval_time:4.43 train_time:19.53
#  #566: steps:22680 interval_time:4.43 train_time:19.52
#  #567: steps:22720 interval_time:4.48 train_time:19.55
#  #568: steps:22760 interval_time:4.43 train_time:19.52
#  #569: steps:22800 interval_time:4.44 train_time:19.52
#  #570: steps:22840 interval_time:4.44 train_time:19.52
#  #571: steps:22880 interval_time:4.44 train_time:19.53
#  #572: steps:22920 interval_time:4.50 train_time:19.50
#  #573: steps:22960 interval_time:4.43 train_time:19.51
#  #574: steps:23000 interval_time:4.45 train_time:19.52
#  #575: steps:23040 interval_time:4.43 train_time:19.51
#  #576: steps:23080 interval_time:4.43 train_time:19.51
#  #577: steps:23120 interval_time:4.43 train_time:19.52
#  #578: steps:23160 interval_time:4.43 train_time:19.53
#  #579: steps:23200 interval_time:4.43 train_time:19.53
#  #580: steps:23240 interval_time:4.46 train_time:19.53
#  #581: steps:23280 interval_time:4.44 train_time:19.52
#  #582: steps:23320 interval_time:4.43 train_time:19.51
#  #583: steps:23360 interval_time:4.43 train_time:19.53
#  #584: steps:23400 interval_time:4.44 train_time:19.53
#  #585: steps:23440 interval_time:4.44 train_time:19.54
#  #586: steps:23480 interval_time:4.46 train_time:19.54
#  #587: steps:23520 interval_time:4.47 train_time:19.56
#  #588: steps:23560 interval_time:4.44 train_time:19.55
#  #589: steps:23600 interval_time:4.46 train_time:19.55
#  #590: steps:23640 interval_time:4.47 train_time:19.54
#  #591: steps:23680 interval_time:4.45 train_time:19.54
#  #592: steps:23720 interval_time:4.52 train_time:19.55
#  #593: steps:23760 interval_time:4.44 train_time:19.51
#  #594: steps:23800 interval_time:4.44 train_time:19.55
#  #595: steps:23840 interval_time:4.46 train_time:19.53
#  #596: steps:23880 interval_time:4.43 train_time:19.54
#  #597: steps:23920 interval_time:4.46 train_time:19.52
#  #598: steps:23960 interval_time:4.44 train_time:19.52
#  #599: steps:24000 interval_time:4.45 train_time:19.53
#  Step_0024039: mean_reward:0.890 mean_dist:0.027 var_dist:0.000
#  #600: steps:24040 interval_time:30.27 train_time:19.52
#  #601: steps:24080 interval_time:4.43 train_time:19.54
#  #602: steps:24120 interval_time:4.44 train_time:19.54
#  #603: steps:24160 interval_time:4.43 train_time:19.51
#  #604: steps:24200 interval_time:4.42 train_time:19.51
#  #605: steps:24240 interval_time:4.43 train_time:19.53
#  #606: steps:24280 interval_time:4.43 train_time:19.51
#  #607: steps:24320 interval_time:4.44 train_time:19.52
#  #608: steps:24360 interval_time:4.45 train_time:19.51
#  #609: steps:24400 interval_time:4.43 train_time:19.51
#  #610: steps:24440 interval_time:4.49 train_time:19.52
#  #611: steps:24480 interval_time:4.52 train_time:19.52
#  #612: steps:24520 interval_time:4.46 train_time:19.55
#  #613: steps:24560 interval_time:4.48 train_time:19.54
#  #614: steps:24600 interval_time:4.43 train_time:19.49
#  #615: steps:24640 interval_time:4.41 train_time:19.50
#  #616: steps:24680 interval_time:4.42 train_time:19.50
#  #617: steps:24720 interval_time:4.43 train_time:19.53
#  #618: steps:24760 interval_time:4.42 train_time:19.51
#  #619: steps:24800 interval_time:4.45 train_time:19.53
#  #620: steps:24840 interval_time:4.43 train_time:19.51
#  #621: steps:24880 interval_time:4.42 train_time:19.51
#  #622: steps:24920 interval_time:4.42 train_time:19.49
#  #623: steps:24960 interval_time:4.49 train_time:19.50
#  #624: steps:25000 interval_time:4.53 train_time:19.53
#  #625: steps:25040 interval_time:4.47 train_time:19.53
#  #626: steps:25080 interval_time:4.42 train_time:19.52
#  #627: steps:25120 interval_time:4.43 train_time:19.52
#  #628: steps:25160 interval_time:4.42 train_time:19.53
#  #629: steps:25200 interval_time:4.43 train_time:19.53
#  #630: steps:25240 interval_time:4.45 train_time:19.50
#  #631: steps:25280 interval_time:4.46 train_time:19.52
#  #632: steps:25320 interval_time:4.45 train_time:19.52
#  #633: steps:25360 interval_time:4.45 train_time:19.50
#  #634: steps:25400 interval_time:4.43 train_time:19.52
#  #635: steps:25440 interval_time:4.43 train_time:19.51
#  #636: steps:25480 interval_time:4.43 train_time:19.53
#  #637: steps:25520 interval_time:4.43 train_time:19.52
#  #638: steps:25560 interval_time:4.44 train_time:19.53
#  #639: steps:25600 interval_time:4.46 train_time:19.52
#  #640: steps:25640 interval_time:4.45 train_time:19.54
#  #641: steps:25680 interval_time:4.43 train_time:19.52
#  #642: steps:25720 interval_time:4.45 train_time:19.51
#  #643: steps:25760 interval_time:4.43 train_time:19.54
#  #644: steps:25800 interval_time:4.44 train_time:19.54
#  #645: steps:25840 interval_time:4.52 train_time:19.51
#  #646: steps:25880 interval_time:4.53 train_time:19.53
#  #647: steps:25920 interval_time:4.49 train_time:19.53
#  #648: steps:25960 interval_time:4.45 train_time:19.53
#  #649: steps:26000 interval_time:4.49 train_time:19.52
#  Step_0026039: mean_reward:0.899 mean_dist:0.025 var_dist:0.000
#  #650: steps:26040 interval_time:30.39 train_time:19.51
#  #651: steps:26080 interval_time:4.44 train_time:19.51
#  #652: steps:26120 interval_time:4.43 train_time:19.51
#  #653: steps:26160 interval_time:4.45 train_time:19.51
#  #654: steps:26200 interval_time:4.44 train_time:19.52
#  #655: steps:26240 interval_time:4.43 train_time:19.53
#  #656: steps:26280 interval_time:4.42 train_time:19.55
#  #657: steps:26320 interval_time:4.43 train_time:19.52
#  #658: steps:26360 interval_time:4.45 train_time:19.53
#  #659: steps:26400 interval_time:4.47 train_time:19.50
#  #660: steps:26440 interval_time:4.42 train_time:19.52
#  #661: steps:26480 interval_time:4.45 train_time:19.53
#  #662: steps:26520 interval_time:4.44 train_time:19.50
#  #663: steps:26560 interval_time:4.43 train_time:19.53
#  #664: steps:26600 interval_time:4.43 train_time:19.53
#  #665: steps:26640 interval_time:4.43 train_time:19.52
#  #666: steps:26680 interval_time:4.46 train_time:19.51
#  #667: steps:26720 interval_time:4.43 train_time:19.51
#  #668: steps:26760 interval_time:4.44 train_time:19.51
#  #669: steps:26800 interval_time:4.46 train_time:19.51
#  #670: steps:26840 interval_time:4.43 train_time:19.53
#  #671: steps:26880 interval_time:4.43 train_time:19.49
#  #672: steps:26920 interval_time:4.45 train_time:19.52
#  #673: steps:26960 interval_time:4.45 train_time:19.53
#  #674: steps:27000 interval_time:4.44 train_time:19.53
#  #675: steps:27040 interval_time:4.45 train_time:19.55
#  #676: steps:27080 interval_time:4.43 train_time:19.55
#  #677: steps:27120 interval_time:4.45 train_time:19.55
#  #678: steps:27160 interval_time:4.46 train_time:19.55
#  #679: steps:27200 interval_time:4.45 train_time:19.55
#  #680: steps:27240 interval_time:4.47 train_time:19.53
#  #681: steps:27280 interval_time:4.47 train_time:19.54
#  #682: steps:27320 interval_time:4.45 train_time:19.55
#  #683: steps:27360 interval_time:4.45 train_time:19.56
#  #684: steps:27400 interval_time:4.43 train_time:19.54
#  #685: steps:27440 interval_time:4.44 train_time:19.56
#  #686: steps:27480 interval_time:4.46 train_time:19.52
#  #687: steps:27520 interval_time:4.46 train_time:19.52
#  #688: steps:27560 interval_time:4.44 train_time:19.52
#  #689: steps:27600 interval_time:4.44 train_time:19.52
#  #690: steps:27640 interval_time:4.45 train_time:19.53
#  #691: steps:27680 interval_time:4.43 train_time:19.55
#  #692: steps:27720 interval_time:4.44 train_time:19.51
#  #693: steps:27760 interval_time:4.43 train_time:19.51
#  #694: steps:27800 interval_time:4.46 train_time:19.52
#  #695: steps:27840 interval_time:4.45 train_time:19.52
#  #696: steps:27880 interval_time:4.42 train_time:19.50
#  #697: steps:27920 interval_time:4.43 train_time:19.50
#  #698: steps:27960 interval_time:4.48 train_time:19.52
#  #699: steps:28000 interval_time:4.43 train_time:19.50
#  Step_0028039: mean_reward:0.903 mean_dist:0.024 var_dist:0.000
#  #700: steps:28040 interval_time:30.53 train_time:19.51
#  #701: steps:28080 interval_time:4.42 train_time:19.49
#  #702: steps:28120 interval_time:4.45 train_time:19.52
#  #703: steps:28160 interval_time:4.46 train_time:19.51
#  #704: steps:28200 interval_time:4.46 train_time:19.51
#  #705: steps:28240 interval_time:4.44 train_time:19.55
#  #706: steps:28280 interval_time:4.46 train_time:19.50
#  #707: steps:28320 interval_time:4.43 train_time:19.52
#  #708: steps:28360 interval_time:4.42 train_time:19.50
#  #709: steps:28400 interval_time:4.46 train_time:19.50
#  #710: steps:28440 interval_time:4.42 train_time:19.50
#  #711: steps:28480 interval_time:4.45 train_time:19.51
#  #712: steps:28520 interval_time:4.46 train_time:19.51
#  #713: steps:28560 interval_time:4.42 train_time:19.51
#  #714: steps:28600 interval_time:4.43 train_time:19.51
#  #715: steps:28640 interval_time:4.44 train_time:19.51
#  #716: steps:28680 interval_time:4.43 train_time:19.50
#  #717: steps:28720 interval_time:4.45 train_time:19.52
#  #718: steps:28760 interval_time:4.44 train_time:19.55
#  #719: steps:28800 interval_time:4.43 train_time:19.51
#  #720: steps:28840 interval_time:4.44 train_time:19.51
#  #721: steps:28880 interval_time:4.43 train_time:19.51
#  #722: steps:28920 interval_time:4.45 train_time:19.49
#  #723: steps:28960 interval_time:4.42 train_time:19.49
#  #724: steps:29000 interval_time:4.43 train_time:19.51
#  #725: steps:29040 interval_time:4.42 train_time:19.49
#  #726: steps:29080 interval_time:4.44 train_time:19.50
#  #727: steps:29120 interval_time:4.47 train_time:19.51
#  #728: steps:29160 interval_time:4.45 train_time:19.48
#  #729: steps:29200 interval_time:4.43 train_time:19.51
#  #730: steps:29240 interval_time:4.43 train_time:19.51
#  #731: steps:29280 interval_time:4.42 train_time:19.53
#  #732: steps:29320 interval_time:4.44 train_time:19.50
#  #733: steps:29360 interval_time:4.43 train_time:19.52
#  #734: steps:29400 interval_time:4.45 train_time:19.55
#  #735: steps:29440 interval_time:4.44 train_time:19.53
#  #736: steps:29480 interval_time:4.43 train_time:19.52
#  #737: steps:29520 interval_time:4.45 train_time:19.54
#  #738: steps:29560 interval_time:4.46 train_time:19.49
#  #739: steps:29600 interval_time:4.43 train_time:19.54
#  #740: steps:29640 interval_time:4.45 train_time:19.52
#  #741: steps:29680 interval_time:4.43 train_time:19.52
#  #742: steps:29720 interval_time:4.46 train_time:19.51
#  #743: steps:29760 interval_time:4.44 train_time:19.52
#  #744: steps:29800 interval_time:4.43 train_time:19.53
#  #745: steps:29840 interval_time:4.44 train_time:19.51
#  #746: steps:29880 interval_time:4.43 train_time:19.50
#  #747: steps:29920 interval_time:4.43 train_time:19.52
#  #748: steps:29960 interval_time:4.44 train_time:19.53
#  #749: steps:30000 interval_time:4.42 train_time:19.51
#  Step_0030039: mean_reward:0.900 mean_dist:0.025 var_dist:0.000
#  #750: steps:30040 interval_time:30.98 train_time:19.52
#  #751: steps:30080 interval_time:4.43 train_time:19.51
#  #752: steps:30120 interval_time:4.43 train_time:19.53
#  #753: steps:30160 interval_time:4.46 train_time:19.53
#  #754: steps:30200 interval_time:4.44 train_time:19.53
#  #755: steps:30240 interval_time:4.45 train_time:19.55
#  #756: steps:30280 interval_time:4.45 train_time:19.54
#  #757: steps:30320 interval_time:4.43 train_time:19.54
#  #758: steps:30360 interval_time:4.45 train_time:19.53
#  #759: steps:30400 interval_time:4.44 train_time:19.52
#  #760: steps:30440 interval_time:4.46 train_time:19.54
#  #761: steps:30480 interval_time:4.45 train_time:19.53
#  #762: steps:30520 interval_time:4.46 train_time:19.53
#  #763: steps:30560 interval_time:4.44 train_time:19.53
#  #764: steps:30600 interval_time:4.55 train_time:19.54
#  #765: steps:30640 interval_time:4.45 train_time:19.55
#  #766: steps:30680 interval_time:4.46 train_time:19.53
#  #767: steps:30720 interval_time:4.49 train_time:19.54
#  #768: steps:30760 interval_time:4.43 train_time:19.53
#  #769: steps:30800 interval_time:4.43 train_time:19.52
#  #770: steps:30840 interval_time:4.45 train_time:19.53
#  #771: steps:30880 interval_time:4.43 train_time:19.54
#  #772: steps:30920 interval_time:4.55 train_time:19.53
#  #773: steps:30960 interval_time:4.45 train_time:19.53
#  #774: steps:31000 interval_time:4.43 train_time:19.54
#  #775: steps:31040 interval_time:4.43 train_time:19.53
#  #776: steps:31080 interval_time:4.44 train_time:19.55
#  #777: steps:31120 interval_time:4.45 train_time:19.55
#  #778: steps:31160 interval_time:4.44 train_time:19.55
#  #779: steps:31200 interval_time:4.45 train_time:19.57
#  #780: steps:31240 interval_time:4.45 train_time:19.55
#  #781: steps:31280 interval_time:4.47 train_time:19.57
#  #782: steps:31320 interval_time:4.47 train_time:19.57
#  #783: steps:31360 interval_time:4.48 train_time:19.55
#  #784: steps:31400 interval_time:4.45 train_time:19.57
#  #785: steps:31440 interval_time:4.43 train_time:19.57
#  #786: steps:31480 interval_time:4.43 train_time:19.55
#  #787: steps:31520 interval_time:4.43 train_time:19.55
#  #788: steps:31560 interval_time:4.44 train_time:19.56
#  #789: steps:31600 interval_time:4.44 train_time:19.54
#  #790: steps:31640 interval_time:4.44 train_time:19.55
#  #791: steps:31680 interval_time:4.43 train_time:19.56
#  #792: steps:31720 interval_time:4.42 train_time:19.54
#  #793: steps:31760 interval_time:4.44 train_time:19.56
#  #794: steps:31800 interval_time:4.43 train_time:19.57
#  #795: steps:31840 interval_time:4.45 train_time:19.54
#  #796: steps:31880 interval_time:4.44 train_time:19.54
#  #797: steps:31920 interval_time:4.43 train_time:19.56
#  #798: steps:31960 interval_time:4.42 train_time:19.53
#  #799: steps:32000 interval_time:4.43 train_time:19.53
#  Step_0032039: mean_reward:0.908 mean_dist:0.022 var_dist:0.000
#  #800: steps:32040 interval_time:30.99 train_time:19.54
#  #801: steps:32080 interval_time:4.43 train_time:19.57
#  #802: steps:32120 interval_time:4.44 train_time:19.55
#  #803: steps:32160 interval_time:4.43 train_time:19.56
#  #804: steps:32200 interval_time:4.44 train_time:19.54
#  #805: steps:32240 interval_time:4.43 train_time:19.55
#  #806: steps:32280 interval_time:4.45 train_time:19.55
#  #807: steps:32320 interval_time:4.49 train_time:19.54
#  #808: steps:32360 interval_time:4.44 train_time:19.54
#  #809: steps:32400 interval_time:4.44 train_time:19.53
#  #810: steps:32440 interval_time:4.43 train_time:19.52
#  #811: steps:32480 interval_time:4.43 train_time:19.54
#  #812: steps:32520 interval_time:4.44 train_time:19.55
#  #813: steps:32560 interval_time:4.44 train_time:19.56
#  #814: steps:32600 interval_time:4.45 train_time:19.55
#  #815: steps:32640 interval_time:4.44 train_time:19.56
#  #816: steps:32680 interval_time:4.46 train_time:19.54
#  #817: steps:32720 interval_time:4.45 train_time:19.55
#  #818: steps:32760 interval_time:4.44 train_time:19.53
#  #819: steps:32800 interval_time:4.43 train_time:19.52
#  #820: steps:32840 interval_time:4.43 train_time:19.54
#  #821: steps:32880 interval_time:4.45 train_time:19.57
#  #822: steps:32920 interval_time:4.45 train_time:19.55
#  #823: steps:32960 interval_time:4.43 train_time:19.56
#  #824: steps:33000 interval_time:4.43 train_time:19.54
#  #825: steps:33040 interval_time:4.43 train_time:19.53
#  #826: steps:33080 interval_time:4.52 train_time:19.57
#  #827: steps:33120 interval_time:4.52 train_time:19.55
#  #828: steps:33160 interval_time:4.53 train_time:19.57
#  #829: steps:33200 interval_time:4.47 train_time:19.56
#  #830: steps:33240 interval_time:4.43 train_time:19.57
#  #831: steps:33280 interval_time:4.44 train_time:19.54
#  #832: steps:33320 interval_time:4.45 train_time:19.53
#  #833: steps:33360 interval_time:4.45 train_time:19.54
#  #834: steps:33400 interval_time:4.46 train_time:19.55
#  #835: steps:33440 interval_time:4.44 train_time:19.54
#  #836: steps:33480 interval_time:4.43 train_time:19.52
#  #837: steps:33520 interval_time:4.43 train_time:19.53
#  #838: steps:33560 interval_time:4.44 train_time:19.53
#  #839: steps:33600 interval_time:4.44 train_time:19.53
# ...
#  #857: steps:34320 interval_time:4.43 train_time:19.53
#  #858: steps:34360 interval_time:4.43 train_time:19.55
#  #859: steps:34400 interval_time:4.44 train_time:19.55
#  #860: steps:34440 interval_time:4.45 train_time:19.54
#  #861: steps:34480 interval_time:4.44 train_time:19.53
#  #862: steps:34520 interval_time:4.44 train_time:19.55
#  #863: steps:34560 interval_time:4.44 train_time:19.53
#  #864: steps:34600 interval_time:4.44 train_time:19.53
#  #865: steps:34640 interval_time:4.44 train_time:19.54
#  #866: steps:34680 interval_time:4.47 train_time:19.53
#  #867: steps:34720 interval_time:4.43 train_time:19.54
#  #868: steps:34760 interval_time:4.43 train_time:19.53
#  #869: steps:34800 interval_time:4.43 train_time:19.53
#  #870: steps:34840 interval_time:4.43 train_time:19.54
#  #871: steps:34880 interval_time:4.44 train_time:19.54
#  #872: steps:34920 interval_time:4.46 train_time:19.53
#  #873: steps:34960 interval_time:4.42 train_time:19.56
#  #874: steps:35000 interval_time:4.43 train_time:19.54
#  #875: steps:35040 interval_time:4.44 train_time:19.54
#  #876: steps:35080 interval_time:4.45 train_time:19.57
#  #877: steps:35120 interval_time:4.44 train_time:19.56
#  #878: steps:35160 interval_time:4.45 train_time:19.58
#  #879: steps:35200 interval_time:4.43 train_time:19.55
#  #880: steps:35240 interval_time:4.45 train_time:19.58
#  #881: steps:35280 interval_time:4.49 train_time:19.56
#  #882: steps:35320 interval_time:4.44 train_time:19.54
#  #883: steps:35360 interval_time:4.45 train_time:19.52
#  #884: steps:35400 interval_time:4.43 train_time:19.53
#  #885: steps:35440 interval_time:4.43 train_time:19.55
#  #886: steps:35480 interval_time:4.44 train_time:19.53
#  #887: steps:35520 interval_time:4.44 train_time:19.53
#  #888: steps:35560 interval_time:4.44 train_time:19.52
#  #889: steps:35600 interval_time:4.42 train_time:19.52
#  #890: steps:35640 interval_time:4.43 train_time:19.52
#  #891: steps:35680 interval_time:4.42 train_time:19.54
#  #892: steps:35720 interval_time:4.42 train_time:19.52
#  #893: steps:35760 interval_time:4.44 train_time:19.53
#  #894: steps:35800 interval_time:4.46 train_time:19.50
#  #895: steps:35840 interval_time:4.42 train_time:19.50
#  #896: steps:35880 interval_time:4.45 train_time:19.51
#  #897: steps:35920 interval_time:4.42 train_time:19.51
#  #898: steps:35960 interval_time:4.43 train_time:19.51
#  #899: steps:36000 interval_time:4.41 train_time:19.49
#  Step_0036039: mean_reward:0.917 mean_dist:0.021 var_dist:0.000
#  #900: steps:36040 interval_time:31.02 train_time:19.49
#  #901: steps:36080 interval_time:4.42 train_time:19.50
#  #902: steps:36120 interval_time:4.43 train_time:19.52
#  #903: steps:36160 interval_time:4.51 train_time:19.54
#  #904: steps:36200 interval_time:4.48 train_time:19.51
#  #905: steps:36240 interval_time:4.43 train_time:19.55
#  #906: steps:36280 interval_time:4.46 train_time:19.57
#  #907: steps:36320 interval_time:4.45 train_time:19.58
#  #908: steps:36360 interval_time:4.46 train_time:19.56
#  #909: steps:36400 interval_time:4.47 train_time:19.53
#  #910: steps:36440 interval_time:4.47 train_time:19.54
#  #911: steps:36480 interval_time:4.45 train_time:19.55
#  #912: steps:36520 interval_time:4.43 train_time:19.54
#  #913: steps:36560 interval_time:4.43 train_time:19.54
#  #914: steps:36600 interval_time:4.43 train_time:19.52
#  #915: steps:36640 interval_time:4.42 train_time:19.53
#  #916: steps:36680 interval_time:4.44 train_time:19.53
#  #917: steps:36720 interval_time:4.43 train_time:19.53
#  #918: steps:36760 interval_time:4.43 train_time:19.53
#  #919: steps:36800 interval_time:4.42 train_time:19.52
#  #920: steps:36840 interval_time:4.43 train_time:19.52
#  #921: steps:36880 interval_time:4.42 train_time:19.54
#  #922: steps:36920 interval_time:4.43 train_time:19.52
#  #923: steps:36960 interval_time:4.46 train_time:19.50
#  #924: steps:37000 interval_time:4.43 train_time:19.51
#  #925: steps:37040 interval_time:4.46 train_time:19.52
#  #926: steps:37080 interval_time:4.43 train_time:19.50
#  #927: steps:37120 interval_time:4.43 train_time:19.51
#  #928: steps:37160 interval_time:4.42 train_time:19.50
#  #929: steps:37200 interval_time:4.41 train_time:19.50
#  #930: steps:37240 interval_time:4.41 train_time:19.50
#  #931: steps:37280 interval_time:4.42 train_time:19.52
#  #932: steps:37320 interval_time:4.41 train_time:19.52
#  #933: steps:37360 interval_time:4.41 train_time:19.50
#  #934: steps:37400 interval_time:4.42 train_time:19.50
#  #935: steps:37440 interval_time:4.41 train_time:19.52
#  #936: steps:37480 interval_time:4.41 train_time:19.48
#  #937: steps:37520 interval_time:4.42 train_time:19.50
#  #938: steps:37560 interval_time:4.42 train_time:19.50
#  #939: steps:37600 interval_time:4.41 train_time:19.50
#  #940: steps:37640 interval_time:4.45 train_time:19.52
#  #941: steps:37680 interval_time:4.43 train_time:19.54
#  #942: steps:37720 interval_time:4.43 train_time:19.52
#  #943: steps:37760 interval_time:4.44 train_time:19.51
#  #944: steps:37800 interval_time:4.42 train_time:19.53
#  #945: steps:37840 interval_time:4.42 train_time:19.52
#  #946: steps:37880 interval_time:4.43 train_time:19.52
#  #947: steps:37920 interval_time:4.44 train_time:19.54
#  #948: steps:37960 interval_time:4.46 train_time:19.53
#  #949: steps:38000 interval_time:4.43 train_time:19.53
#  Step_0038039: mean_reward:0.920 mean_dist:0.020 var_dist:0.000
#  #950: steps:38040 interval_time:31.03 train_time:19.53
#  #951: steps:38080 interval_time:4.44 train_time:19.51
#  #952: steps:38120 interval_time:4.43 train_time:19.52
#  #953: steps:38160 interval_time:4.44 train_time:19.52
#  #954: steps:38200 interval_time:4.45 train_time:19.53
#  #955: steps:38240 interval_time:4.46 train_time:19.52
#  #956: steps:38280 interval_time:4.42 train_time:19.52
#  #957: steps:38320 interval_time:4.43 train_time:19.54
#  #958: steps:38360 interval_time:4.43 train_time:19.54
#  #959: steps:38400 interval_time:4.43 train_time:19.55
#  #960: steps:38440 interval_time:4.42 train_time:19.52
#  #961: steps:38480 interval_time:4.43 train_time:19.53
#  #962: steps:38520 interval_time:4.42 train_time:19.50
#  #963: steps:38560 interval_time:4.42 train_time:19.51
#  #964: steps:38600 interval_time:4.43 train_time:19.51
#  #965: steps:38640 interval_time:4.44 train_time:19.51
#  #966: steps:38680 interval_time:4.42 train_time:19.50
#  #967: steps:38720 interval_time:4.42 train_time:19.49
#  #968: steps:38760 interval_time:4.41 train_time:19.50
#  #969: steps:38800 interval_time:4.46 train_time:19.52
#  #970: steps:38840 interval_time:4.42 train_time:19.51
#  #971: steps:38880 interval_time:4.46 train_time:19.52
#  #972: steps:38920 interval_time:4.43 train_time:19.51
#  #973: steps:38960 interval_time:4.43 train_time:19.49
#  #974: steps:39000 interval_time:4.43 train_time:19.50
#  #975: steps:39040 interval_time:4.42 train_time:19.49
#  #976: steps:39080 interval_time:4.51 train_time:19.49
#  #977: steps:39120 interval_time:4.51 train_time:19.50
#  #978: steps:39160 interval_time:4.43 train_time:19.50
#  #979: steps:39200 interval_time:4.42 train_time:19.48
#  #980: steps:39240 interval_time:4.42 train_time:19.48
#  #981: steps:39280 interval_time:4.41 train_time:19.49
#  #982: steps:39320 interval_time:4.46 train_time:19.50
#  #983: steps:39360 interval_time:4.43 train_time:19.48
#  #984: steps:39400 interval_time:4.49 train_time:19.49
#  #985: steps:39440 interval_time:4.44 train_time:19.50
#  #986: steps:39480 interval_time:4.43 train_time:19.48
#  #987: steps:39520 interval_time:4.42 train_time:19.47
#  #988: steps:39560 interval_time:4.41 train_time:19.47
#  #989: steps:39600 interval_time:4.42 train_time:19.49
#  #990: steps:39640 interval_time:4.44 train_time:19.49
#  #991: steps:39680 interval_time:4.43 train_time:19.48
#  #992: steps:39720 interval_time:4.43 train_time:19.49
#  #993: steps:39760 interval_time:4.42 train_time:19.49
#  #994: steps:39800 interval_time:4.42 train_time:19.51
#  #995: steps:39840 interval_time:4.43 train_time:19.50
#  #996: steps:39880 interval_time:4.45 train_time:19.51
#  #997: steps:39920 interval_time:4.41 train_time:19.48
#  #998: steps:39960 interval_time:4.43 train_time:19.49
#  #999: steps:40000 interval_time:4.47 train_time:19.51
#  Step_0040039: mean_reward:0.924 mean_dist:0.019 var_dist:0.000
#  #1000: steps:40040 interval_time:32.87 train_time:19.42
#  #1001: steps:40080 interval_time:4.41 train_time:19.41
#  #1002: steps:40120 interval_time:4.41 train_time:19.40
#  #1003: steps:40160 interval_time:4.43 train_time:19.44
#  #1004: steps:40200 interval_time:4.44 train_time:19.45
#  #1005: steps:40240 interval_time:4.43 train_time:19.46
#  #1006: steps:40280 interval_time:4.45 train_time:19.46
#  #1007: steps:40320 interval_time:4.43 train_time:19.46
#  #1008: steps:40360 interval_time:4.43 train_time:19.46
#  #1009: steps:40400 interval_time:4.49 train_time:19.45
#  #1010: steps:40440 interval_time:4.51 train_time:19.45
#  #1011: steps:40480 interval_time:4.42 train_time:19.47
#  #1012: steps:40520 interval_time:4.49 train_time:19.44
#  #1013: steps:40560 interval_time:4.44 train_time:19.48
#  #1014: steps:40600 interval_time:4.43 train_time:19.45
#  #1015: steps:40640 interval_time:4.43 train_time:19.46
#  #1016: steps:40680 interval_time:4.43 train_time:19.43
#  #1017: steps:40720 interval_time:4.43 train_time:19.47
#  #1018: steps:40760 interval_time:4.43 train_time:19.45
#  #1019: steps:40800 interval_time:4.45 train_time:19.47
#  #1020: steps:40840 interval_time:4.44 train_time:19.46
#  #1021: steps:40880 interval_time:4.43 train_time:19.46
#  #1022: steps:40920 interval_time:4.43 train_time:19.45
#  #1023: steps:40960 interval_time:4.43 train_time:19.46
#  #1024: steps:41000 interval_time:4.46 train_time:19.46
#  #1025: steps:41040 interval_time:4.44 train_time:19.47
#  #1026: steps:41080 interval_time:4.44 train_time:19.46
#  #1027: steps:41120 interval_time:4.44 train_time:19.47
#  #1028: steps:41160 interval_time:4.47 train_time:19.46
#  #1029: steps:41200 interval_time:4.46 train_time:19.45
#  #1030: steps:41240 interval_time:4.44 train_time:19.45
#  #1031: steps:41280 interval_time:4.44 train_time:19.44
#  #1032: steps:41320 interval_time:4.44 train_time:19.45
#  #1033: steps:41360 interval_time:4.43 train_time:19.46
#  #1034: steps:41400 interval_time:4.43 train_time:19.48
#  #1035: steps:41440 interval_time:4.43 train_time:19.45
#  #1036: steps:41480 interval_time:4.45 train_time:19.47
#  #1037: steps:41520 interval_time:4.43 train_time:19.45
#  #1038: steps:41560 interval_time:4.42 train_time:19.45
#  #1039: steps:41600 interval_time:4.43 train_time:19.45
#  #1040: steps:41640 interval_time:4.43 train_time:19.46
#  #1041: steps:41680 interval_time:4.42 train_time:19.45
#  #1042: steps:41720 interval_time:4.44 train_time:19.44
#  #1043: steps:41760 interval_time:4.51 train_time:19.44
#  #1044: steps:41800 interval_time:4.43 train_time:19.46
#  #1045: steps:41840 interval_time:4.42 train_time:19.46
#  #1046: steps:41880 interval_time:4.43 train_time:19.46
#  #1047: steps:41920 interval_time:4.45 train_time:19.45
#  #1048: steps:41960 interval_time:4.46 train_time:19.46
#  #1049: steps:42000 interval_time:4.44 train_time:19.45
#  Step_0042039: mean_reward:0.936 mean_dist:0.016 var_dist:0.000
#  #1050: steps:42040 interval_time:33.20 train_time:19.45
#  #1051: steps:42080 interval_time:4.42 train_time:19.47
#  #1052: steps:42120 interval_time:4.42 train_time:19.46
#  #1053: steps:42160 interval_time:4.42 train_time:19.45
#  #1054: steps:42200 interval_time:4.41 train_time:19.45
#  #1055: steps:42240 interval_time:4.42 train_time:19.45
#  #1056: steps:42280 interval_time:4.46 train_time:19.45
#  #1057: steps:42320 interval_time:4.45 train_time:19.46
#  #1058: steps:42360 interval_time:4.43 train_time:19.45
#  #1059: steps:42400 interval_time:4.42 train_time:19.47
#  #1060: steps:42440 interval_time:4.43 train_time:19.45
#  #1061: steps:42480 interval_time:4.42 train_time:19.47
#  #1062: steps:42520 interval_time:4.43 train_time:19.46
#  #1063: steps:42560 interval_time:4.46 train_time:19.47
#  #1064: steps:42600 interval_time:4.43 train_time:19.46
#  #1065: steps:42640 interval_time:4.43 train_time:19.48
#  #1066: steps:42680 interval_time:4.43 train_time:19.48
#  #1067: steps:42720 interval_time:4.45 train_time:19.47
#  #1068: steps:42760 interval_time:4.45 train_time:19.47
#  #1069: steps:42800 interval_time:4.44 train_time:19.46
#  #1070: steps:42840 interval_time:4.44 train_time:19.46
#  #1071: steps:42880 interval_time:4.43 train_time:19.45
#  #1072: steps:42920 interval_time:4.47 train_time:19.46
#  #1073: steps:42960 interval_time:4.43 train_time:19.46
#  #1074: steps:43000 interval_time:4.43 train_time:19.46
#  #1075: steps:43040 interval_time:4.45 train_time:19.45
#  #1076: steps:43080 interval_time:4.43 train_time:19.47
#  #1077: steps:43120 interval_time:4.46 train_time:19.48
#  #1078: steps:43160 interval_time:4.43 train_time:19.48
#  #1079: steps:43200 interval_time:4.44 train_time:19.46
#  #1080: steps:43240 interval_time:4.46 train_time:19.47
#  #1081: steps:43280 interval_time:4.41 train_time:19.46
#  #1082: steps:43320 interval_time:4.44 train_time:19.47
#  #1083: steps:43360 interval_time:4.43 train_time:19.47
#  #1084: steps:43400 interval_time:4.42 train_time:19.47
#  #1085: steps:43440 interval_time:4.43 train_time:19.48
#  #1086: steps:43480 interval_time:4.45 train_time:19.47
#  #1087: steps:43520 interval_time:4.52 train_time:19.46
#  #1088: steps:43560 interval_time:4.44 train_time:19.46
#  #1089: steps:43600 interval_time:4.43 train_time:19.48
#  #1090: steps:43640 interval_time:4.43 train_time:19.45
#  #1091: steps:43680 interval_time:4.42 train_time:19.47
#  #1092: steps:43720 interval_time:4.43 train_time:19.47
#  #1093: steps:43760 interval_time:4.43 train_time:19.46
#  #1094: steps:43800 interval_time:4.41 train_time:19.47
#  #1095: steps:43840 interval_time:4.42 train_time:19.47
#  #1096: steps:43880 interval_time:4.43 train_time:19.48
#  #1097: steps:43920 interval_time:4.42 train_time:19.46
#  #1098: steps:43960 interval_time:4.46 train_time:19.45
#  #1099: steps:44000 interval_time:4.43 train_time:19.46
#  Step_0044039: mean_reward:0.937 mean_dist:0.015 var_dist:0.000
#  #1100: steps:44040 interval_time:32.69 train_time:19.46
#  #1101: steps:44080 interval_time:4.44 train_time:19.46
#  #1102: steps:44120 interval_time:4.42 train_time:19.46
#  #1103: steps:44160 interval_time:4.41 train_time:19.45
#  #1104: steps:44200 interval_time:4.44 train_time:19.46
#  #1105: steps:44240 interval_time:4.43 train_time:19.46
#  #1106: steps:44280 interval_time:4.43 train_time:19.45
#  #1107: steps:44320 interval_time:4.42 train_time:19.44
#  #1108: steps:44360 interval_time:4.40 train_time:19.45
#  #1109: steps:44400 interval_time:4.41 train_time:19.45
#  #1110: steps:44440 interval_time:4.40 train_time:19.44
#  #1111: steps:44480 interval_time:4.41 train_time:19.46
#  #1112: steps:44520 interval_time:4.43 train_time:19.46
#  #1113: steps:44560 interval_time:4.48 train_time:19.46
#  #1114: steps:44600 interval_time:4.51 train_time:19.46
#  #1115: steps:44640 interval_time:4.44 train_time:19.44
#  #1116: steps:44680 interval_time:4.47 train_time:19.44
#  #1117: steps:44720 interval_time:4.42 train_time:19.45
#  #1118: steps:44760 interval_time:4.44 train_time:19.45
#  #1119: steps:44800 interval_time:4.41 train_time:19.45
#  #1120: steps:44840 interval_time:4.42 train_time:19.45
#  #1121: steps:44880 interval_time:4.40 train_time:19.44
#  #1122: steps:44920 interval_time:4.41 train_time:19.46
#  #1123: steps:44960 interval_time:4.41 train_time:19.44
#  #1124: steps:45000 interval_time:4.41 train_time:19.44
#  #1125: steps:45040 interval_time:4.48 train_time:19.45
#  #1126: steps:45080 interval_time:4.41 train_time:19.46
#  #1127: steps:45120 interval_time:4.41 train_time:19.47
#  #1128: steps:45160 interval_time:4.42 train_time:19.44
#  #1129: steps:45200 interval_time:4.42 train_time:19.45
#  #1130: steps:45240 interval_time:4.44 train_time:19.45
#  #1131: steps:45280 interval_time:4.48 train_time:19.45
#  #1132: steps:45320 interval_time:4.41 train_time:19.44
#  #1133: steps:45360 interval_time:4.41 train_time:19.45
#  #1134: steps:45400 interval_time:4.40 train_time:19.44
#  #1135: steps:45440 interval_time:4.40 train_time:19.42
#  #1136: steps:45480 interval_time:4.44 train_time:19.45
#  #1137: steps:45520 interval_time:4.46 train_time:19.45
#  #1138: steps:45560 interval_time:4.42 train_time:19.47
